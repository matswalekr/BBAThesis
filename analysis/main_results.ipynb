# %% [markdown]
# # Main results

# %% [markdown]
# ## 1. Build model

# %%
from src import download_save_raw_data, clean_save_data, create_save_portfolios, build_save_model 
from configs import CONFIG

# %% [markdown]
# ### 1.a. Download data (Resource intensive)

# %%
download_save_raw_data(CONFIG)
# Out:
# Loading library list...
# Done

# %% [markdown]
# ### 1.b. Process data (Resource intensive)

# %%
clean_save_data(CONFIG)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 clean_save_data(CONFIG)
#
# File ~/Downloads/FinalThesis/src/data_cleaning.py:395, in clean_save_data(config)
#     376 def clean_save_data(config: CONFIGURATION) -> None:
#     377     """
#     378     Function to clean and save the entire data.
#     379
#    (...)
#     386     -------
#     387     None"""
#     389     (
#     390         factors_monthly_processed,
#     391         factors_yearly_processed,
#     392         stock_prices_intersected,
#     393         firm_info_processed,
#     394         sic_desc_processed,
# --> 395     ) = clean_data(config)
#     397     save_processed_data(
#     398         factors_monthly_processed,
#     399         factors_yearly_processed,
#    (...)
#     403         config,
#     404     )
#
# ...

# %% [markdown]
# ### 1.c. Create the portfolios

# %%
create_save_portfolios(CONFIG)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 create_save_portfolios(CONFIG)
#
# File ~/Downloads/FinalThesis/src/create_portfolios.py:630, in create_save_portfolios(config)
#     616 """
#     617 Function to run the entire portfolio creation and return calculation pipeline.
#     618
#    (...)
#     627     This function runs the pipeline and saves the results to CSV files.
#     628 """
#     629 # Create the portfolios and their returns
# --> 630 portfolio_returns, portfolio_constitution = create_portfolios_and_returns(config)
#     632 # Save the results
#     633 save_portfolio_returns_constitution(
#     634     portfolio_returns=portfolio_returns,
#     635     portfolio_constitution=portfolio_constitution,
#     636     config=config,
#     637 )
#
# ...

# %% [markdown]
# ### 1.d. Create the model and run the regression

# %%
build_save_model(CONFIG)
